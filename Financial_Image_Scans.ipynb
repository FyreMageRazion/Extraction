# %% [markdown]
# ###  AI-powered Financial Image Scans - Report Analysis
# Focusing mainly on image extraction

# %%
from PIL import Image
import requests
from io import BytesIO
import google.generativeai as genai

# %%
google_api_key = "<API_KEY>"

# %%
genai.configure(api_key=google_api_key)
model = genai.GenerativeModel("gemini-2.0-flash")

# %%
image_urls = [
    "https://go.forrester.com/wp-content/uploads/2023/11/apple-profits-blog.png",
    "https://go.forrester.com/wp-content/uploads/2023/11/jitender-apple-blog.png",
    "https://images.macrumors.com/t/Bb--zHHKC4ein3n5iMP5i-chFKI=/1600x0/article-new/2023/11/aapl-4q23-line.jpg",
    "https://images.macrumors.com/t/c6RiQUc_qqIsdywTw3HQ0_Wmpes=/1600x0/article-new/2023/11/aapl-4q23-pie.jpg",
    "https://i0.wp.com/sixcolors.com/wp-content/uploads/2023/11/financialsx-2023-11-1-1.png?ssl=1",
    "https://i0.wp.com/sixcolors.com/wp-content/uploads/2023/11/financialsx-2023-11-1-2.png?ssl=1",
    "https://i0.wp.com/sixcolors.com/wp-content/uploads/2023/11/financialsx-2023-11-1-3.png?ssl=1",
    "https://i0.wp.com/sixcolors.com/wp-content/uploads/2023/11/financialsx-2023-11-1-4.png?ssl=1",
    "https://i0.wp.com/sixcolors.com/wp-content/uploads/2023/11/financialsx-2023-11-2-1.png?ssl=1",
    "https://i0.wp.com/sixcolors.com/wp-content/uploads/2023/11/financialsx-2023-11-2-2.png?ssl=1",
    "https://i0.wp.com/sixcolors.com/wp-content/uploads/2023/11/financialsx-2023-11-2-3.png?ssl=1",
    "https://i0.wp.com/sixcolors.com/wp-content/uploads/2023/11/financialsx-2023-11-2-4.png?ssl=1",
    "https://i0.wp.com/sixcolors.com/wp-content/uploads/2023/11/financialsx-2023-11-3-2.png?ssl=1",
    "https://i0.wp.com/sixcolors.com/wp-content/uploads/2023/11/financialsx-2023-11-3-3.png?ssl=1",
]

# %%
def load_images(urls):
    images = []
    for url in urls:
        try:
            response = requests.get(url, timeout=15)
            response.raise_for_status()
            img = Image.open(BytesIO(response.content)).convert("RGB")
            images.append(img)
        except Exception as e:
            print(f"Error loading {url}: {e}")
    return images

images = load_images(image_urls)

# %%
prompt = """Analyze and summarize the content from the following list of images. Perform a detailed extraction of all textual, numerical, and visual information (including charts, tables, captions, and annotations).

Objective:
Generate a comprehensive executive report that consolidates insights from all images into a cohesive narrative. The report should read like a professional analyst brief or financial summary, with logical structure and data-driven commentary.

Instructions:

Scan and Extract

Identify and transcribe all visible text, data points, and numerical figures from charts, graphs, and tables.

Capture any labels, units, and contextual details.

Note any brand, source, or date references for context.

Analyze and Synthesize

Identify key themes, trends, and correlations across the images (e.g., performance trends, segment breakdowns, growth patterns, or financial ratios).

Compare quarterly or year-over-year data where applicable.

Translate visual information (like bar charts, pie charts, and line graphs) into clear textual summaries.

Report Structure:
Organize findings into the following sections (add or adjust as necessary based on content):

Executive Summary – Core findings, key takeaways, and overall message of the visuals.

Financial Overview / Performance Summary – Revenues, profits, margins, growth trends, or equivalent.

Segment or Product Analysis – Insights by category, business unit, or product line.

Geographic Breakdown – Regional revenue/profit analysis if applicable.

Trends and Comparative Insights – Year-over-year or quarter-over-quarter observations.

Risks, Challenges, and Opportunities – Interpretive commentary based on the data.

Conclusion and Strategic Implications – A synthesized outlook or strategic takeaway.

Tone and Style:

Use concise, data-backed business language.

Write as though preparing for senior executives or investors.

Avoid redundancy; emphasize insights, not just raw data.

Include percentages, growth rates, and margins where visible.

Output Format:
Present the final output as a well-structured text report with proper headings, bullet points, and clear segmentation."""

# %%
model = genai.GenerativeModel("gemini-2.5-flash")
response = model.generate_content([prompt, *images])

print(response.text)
# Out:
# ## Executive Report: Apple Inc. Financial and Segment Performance Analysis (FY2021-FY2023 and Quarterly Trends)
#
# **Date:** November 2, 2023 (based on source dates)
#
# ### Executive Summary
#
# Apple Inc. experienced a significant shift in its growth trajectory in Fiscal Year 2023 (FY23), with total net sales declining by 3% year-over-year to $383 billion. This marks a deceleration from the robust 8% growth seen in FY22. While product categories like Mac, iPad, and Wearables faced notable year-over-year revenue contractions, the Services segment continued its consistent growth, albeit at a slower pace than previous periods, and now accounts for a growing share of total revenue and a substantial portion of gross profit. Profitability metrics, particularly gross margin, showed resilience and improvement as a percentage of revenue, driven by the high-margin Services business. However, operating expenses have risen as a share of revenue. Geographically, most major markets, including the Americas, Europe, Greater China, and Japan, saw revenue declines in FY23, with only the Rest of Asia Pacific showing modest growth. The company faces the challenge of revitalizing product sales while capitalizing on the strong and stable performance of its Services ecosystem.
#
# ### Financial Overview / Performance Summary
#
# **Total Net Sales:**
# *   FY21: $366 billion
# *   FY22: $394 billion (8% YoY growth)
# *   FY23: $383 billion (-3% YoY decline)
#
# **Profitability:**
# *   **Gross Income:**
#     *   FY21: $153 billion (42% of total revenues)
#     *   FY22: $171 billion (43% of total revenues)
#     *   FY23: $169 billion (44% of total revenues)
#     *   *Insight:* Gross margin percentage has steadily improved over the three fiscal years, indicating effective cost management or a favorable shift in sales mix towards higher-margin offerings.
# *   **Operating Expenses:**
#     *   FY21: $44 billion (12% of total revenues)
#     *   FY22: $51 billion (13% of total revenues)
#     *   FY23: $55 billion (14% of total revenues)
#     *   *Insight:* Operating expenses have grown faster than revenue, increasing as a percentage of total revenues.
# *   **Operating Income:**
#     *   FY21: $109 billion (30% of total revenues)
#     *   FY22: $119 billion (30% of total revenues)
#     *   FY23: $114 billion (30% of total revenues)
#     *   *Insight:* Operating income saw a slight absolute decline in FY23 but maintained its 30% share of total revenues, suggesting strong underlying operational efficiency despite revenue pressure.
# *   **Net Income:**
#     *   FY21: $9 billion (3% of total revenues) - *Note: This figure for FY21 appears exceptionally low compared to the operating income and subsequent years, which might indicate a one-time significant charge or accounting adjustment in that specific year.*
#     *   FY22: $100 billion (25% of total revenues)
#     *   FY23: $97 billion (25% of total revenues)
#     *   *Insight:* Net income declined slightly in absolute terms in FY23 but maintained a 25% share of total revenues, stable with FY22.
#
# ### Segment or Product Analysis
#
# **Revenue Contribution and Growth:**
# *   **Products:**
#     *   FY23 Sales: $298 billion (78% of total sales)
#     *   YoY Growth FY23: -6%
#     *   Gross Margin: 37% (FY23), stable around 35-37% over three years.
# *   **Services:**
#     *   FY23 Sales: $85 billion (22% of total sales)
#     *   YoY Growth FY23: +9%
#     *   Gross Margin: 71% (FY23), stable around 70-72% over three years.
#     *   *Insight:* Services continues to be a high-growth, high-margin segment, steadily increasing its share of total revenue and profitability, effectively offsetting declines in product sales.
#
# **Breakdown by Groups of Products/Services (FY23 and Q4 FY23):**
# *   **iPhone:**
#     *   FY23 Sales: $201 billion (52% of total sales)
#     *   YoY Growth FY23: -7%
#     *   Q4 FY23 Revenue: 48.9% of total Q4 revenue.
#     *   *Insight:* Despite a -7% decline in FY23, iPhone remains the dominant revenue driver for Apple, though its growth has turned negative. Quarterly growth for iPhone has been volatile (Q1 23: -8%, Q2 23: +2%, Q3 23: -2%, Q4 23: +3%).
# *   **Services:**
#     *   FY23 Sales: $85 billion (22% of total sales)
#     *   YoY Growth FY23: +9%
#     *   Q4 FY23 Revenue: 24.9% of total Q4 revenue.
#     *   *Insight:* Services demonstrated consistent YOY growth (6% in Q1 23, 8% in Q2 23, 5% in Q3 23, 16% in Q4 23), accelerating towards the end of FY23 after a period of deceleration. It is the most stable growth engine.
# *   **Wearables, Home & Accessories:**
#     *   FY23 Sales: $40 billion (10% of total sales)
#     *   YoY Growth FY23: -3%
#     *   Q4 FY23 Revenue: 10.4% of total Q4 revenue.
#     *   *Insight:* This category, after periods of very high growth (e.g., +54% in Q4 19), has entered a contraction phase with multiple consecutive YOY declines in FY23 (Q1 23: -1%, Q2 23: -8%, Q3 23: -1%, Q4 23: -3%).
# *   **Mac:**
#     *   FY23 Sales: $28 billion (7% of total sales)
#     *   YoY Growth FY23: -27%
#     *   Q4 FY23 Revenue: 8.5% of total Q4 revenue.
#     *   *Insight:* Mac experienced severe YOY declines throughout FY23 (Q1 23: -29%, Q2 23: -31%, Q3 23: -7%, Q4 23: -34%), reversing strong growth seen in earlier years.
# *   **iPad:**
#     *   FY23 Sales: $29 billion (7% of total sales)
#     *   YoY Growth FY23: -3%
#     *   Q4 FY23 Revenue: 7.2% of total Q4 revenue.
#     *   *Insight:* iPad revenue has also been declining on a YOY basis for most of FY23 (Q1 23: -13%, Q2 23: -20%, Q3 23: -10%, Q4 23: -10%), following a period of strong performance.
#
# ### Geographic Breakdown
#
# **Net Sales by Regions (FY23):**
# *   **Americas:** $163 billion (42% of total sales), -1% YoY growth.
# *   **Europe:** $94 billion (25% of total sales), -4% YoY growth.
# *   **Greater China:** $73 billion (19% of total sales), -1% YoY growth.
# *   **Japan:** $24 billion (6% of total sales), -7% YoY growth.
# *   **Rest of Asia Pacific:** $30 billion (8% of total sales), +1% YoY growth.
# *   *Insight:* Almost all major geographic regions experienced YOY sales contractions in FY23, with Japan seeing the steepest decline. Rest of Asia Pacific was the only region to register positive growth.
#
# ### Trends and Comparative Insights
#
# *   **Overall Revenue Deceleration:** After a period of consistent strong growth, Apple's total net sales saw a 3% decline in FY23, indicating a challenging macroeconomic environment and/or market saturation for key product lines.
# *   **Shifting Revenue Mix:** The Services segment's share of total sales has steadily increased from 19% in FY21 to 22% in FY23, highlighting its growing importance as product revenue stagnates or declines.
# *   **Product Cycle Volatility:** The detailed quarterly charts reveal the cyclical and often volatile nature of product revenues, particularly for Mac, iPad, and Wearables, which have moved from periods of high double-digit growth to significant contractions. iPhone revenue, while still dominant, has shown less consistent growth in FY23 compared to earlier periods.
# *   **Seasonality:** Quarterly revenue consistently peaks in Q1 (Apple's holiday quarter), demonstrating strong seasonal purchasing patterns.
# *   **Profitability Stability:** Despite revenue fluctuations, the gross and operating income as a percentage of revenue have remained stable or even improved (for gross margin), underpinned by the higher-margin Services business.
#
# ### Risks, Challenges, and Opportunities
#
# **Risks & Challenges:**
# *   **Product Dependence and Contraction:** Over-reliance on iPhone, coupled with significant YOY declines in Mac, iPad, and Wearables categories, poses a risk to overall revenue growth.
# *   **Geographic Headwinds:** Widespread revenue declines across major markets signal broad challenges, potentially from economic slowdowns, increased competition, or geopolitical factors.
# *   **Operating Expense Growth:** The increase in operating expenses as a percentage of revenue could compress margins if revenue growth does not resume.
# *   **Innovation Cycle:** The recent declines in product categories suggest that the current product lineup may not be driving sufficient upgrades or new user adoption.
#
# **Opportunities:**
# *   **Services Ecosystem Expansion:** Continued investment in and expansion of the Services segment (e.g., Apple Music, iCloud, App Store, Apple TV+, Fitness+, Apple Pay) can further stabilize and grow high-margin recurring revenue. The strong Q4 23 Services growth (16%) is a positive indicator.
# *   **Emerging Market Growth:** The positive growth in Rest of Asia Pacific suggests opportunities for targeted market expansion and penetration.
# *   **Next-Generation Products:** Future innovation, such as the upcoming Vision Pro or other new product categories, could reignite product-driven growth and excite the market.
# *   **Customer Loyalty:** Leveraging its strong brand and customer ecosystem can help retain users and encourage adoption of new services and product upgrades.
#
# ### Conclusion and Strategic Implications
#
# Apple Inc. is navigating a period of revenue contraction, primarily driven by declines across most of its product categories. The Services segment stands out as a critical and increasingly important growth engine, offering high margins and a stable revenue stream that is essential for offsetting product volatility.
#
# Strategically, Apple must:
# 1.  **Accelerate Services Growth:** Continue to innovate and expand its Services offerings to deepen customer engagement and capture a larger share of consumer spending.
# 2.  **Reignite Product Innovation:** Focus on compelling upgrades and new product introductions to stimulate demand in mature categories like Mac and iPad, and address the declining momentum in Wearables.
# 3.  **Optimize Geographic Performance:** Implement tailored strategies to address regional market specificities, particularly in regions experiencing significant declines.
# 4.  **Maintain Operational Discipline:** Balance investment in growth areas with careful management of operating expenses to preserve profitability during a challenging revenue cycle.
#
# The company's strong brand, loyal customer base, and robust cash flow provide a solid foundation, but sustained growth will require renewed product momentum alongside the continued expansion of its high-margin Services ecosystem.
