# %% [markdown]
# # Financial Research Agent - Router -> [web search/RAG/LLM] -> Summarizing
# ## Please note that this notebook uses the latest way to create and use ReAct agents and OpenAI models using Langchain
#
# ### PLease visit https://docs.langchain.com/oss/python/langchain/agents and https://docs.langchain.com/oss/python/integrations/chat/openai for more details

# %%
#!pip install -qU langchain langchain_openai langgraph openbb openbb-yfinance

# %%
import os
import json
import re
import os
import numpy as np
import json
import requests
from typing import Dict, Any, List, Optional
from typing import TypedDict, Literal
from bs4 import BeautifulSoup

from langchain.tools import tool
from langchain.agents import create_agent
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import FAISS

from langchain_community.tools.tavily_search import TavilySearchResults

from langgraph.graph import StateGraph, END
from langchain_core.messages import SystemMessage, HumanMessage
from langchain_openai import ChatOpenAI
from langchain_core.messages import AIMessage
from langgraph.graph import StateGraph, START, END
from typing import TypedDict, Annotated, List, Union, Literal
from langchain_core.messages import BaseMessage
from operator import itemgetter
from langchain_core.messages import HumanMessage, AIMessage

import pandas as pd
import glob
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters  import RecursiveCharacterTextSplitter

from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_community.vectorstores import FAISS

from sentence_transformers import CrossEncoder

# %%
tavily_api_key = "<API KEY>"
openai_api_key = "<API KEY>"

os.environ["OPENAI_API_KEY"] = openai_api_key
os.environ["TAVILY_API_KEY"] = tavily_api_key

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
TAVILY_API_KEY = os.getenv("TAVILY_API_KEY")

HEADERS = {"User-Agent": "FinancialAssistant/1.0"}

# %% [markdown]
# ## RAG Implementation
#
# ### The RAG mode will be selected only if the query is related to Netflix and/or Oracle as two PDFs are in the RAG folder processed.

# %%
DATA_DIR = "Financial_Docs"

def load_all_pdfs(path):
    docs = []
    for pdf_file in glob.glob(f"{path}/*.pdf"):
        loader = PyPDFLoader(pdf_file)
        pages = loader.load()
        for p in pages:
            p.metadata["source"] = os.path.basename(pdf_file)
        docs.extend(pages)
    return docs

raw_docs = load_all_pdfs(DATA_DIR)

splitter = RecursiveCharacterTextSplitter(
    chunk_size=800,
    chunk_overlap=200
)

chunked_docs = splitter.split_documents(raw_docs)

# Attach chunk indices
for idx, doc in enumerate(chunked_docs):
    doc.metadata["chunk_index"] = idx

# %%
chunked_docs[:2]
# Out:
# [Document(metadata={'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creator': 'EDGAR Filing HTML Converter', 'creationdate': '2025-10-22T16:03:23-04:00', 'title': '0001065280-25-000406', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-Q filed on 2025-10-22 for the period ending 2025-09-30', 'keywords': '0001065280-25-000406; ; 10-Q', 'moddate': '2025-10-22T16:03:31-04:00', 'source': 'Netflix.pdf', 'total_pages': 42, 'page': 0, 'page_label': '1', 'chunk_index': 0}, page_content='UNITED STATES\nSECURITIES AND EXCHANGE COMMISSION\nWashington, D.C. 20549\nFORM 10-Q\n(Mark One)\n☒  QUARTERLY REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF 1934\nFor the quarterly period ended September 30, 2025\nOR\n☐  TRANSITION REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF 1934\nFor the transition period from                  to                 \nCommission File Number: 001-35727\nNetflix, Inc.\n(Exact name of Registrant as specified in its charter)\nDelaware 77-0467272\n(State or other jurisdiction ofincorporation or organization) (I.R.S. EmployerIdentification Number)\n121 Albright Way, Los Gatos, California 95032\n(Address of principal executive offices) (Zip Code)\n(408) 540-3700\n(Registrant’s telephone number, including area code)'),
#  Document(metadata={'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creator': 'EDGAR Filing HTML Converter', 'creationdate': '2025-10-22T16:03:23-04:00', 'title': '0001065280-25-000406', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-Q filed on 2025-10-22 for the period ending 2025-09-30', 'keywords': '0001065280-25-000406; ; 10-Q', 'moddate': '2025-10-22T16:03:31-04:00', 'source': 'Netflix.pdf', 'total_pages': 42, 'page': 0, 'page_label': '1', 'chunk_index': 1}, page_content='121 Albright Way, Los Gatos, California 95032\n(Address of principal executive offices) (Zip Code)\n(408) 540-3700\n(Registrant’s telephone number, including area code)\nSecurities registered pursuant to Section 12(b) of the Act:\nTitle of each class Trading Symbol(s) Name of each exchange on which registered\nCommon stock, par value $0.001 per share NFLX NASDAQ Global Select Market\nIndicate by check mark whether the registrant (1) has filed all reports required to be filed by Section 13 or 15(d) of the Securities Exchange Act of 1934 during the\npreceding 12 months (or for such shorter period that the registrant was required to file such reports) and (2) has been subject to such filing requirements for the past 90\ndays.    Yes  ☒     No  ☐')]

# %%
emb = OpenAIEmbeddings(model="text-embedding-3-small")

vectorstore = FAISS.from_documents(chunked_docs, emb)
retriever = vectorstore.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 12}  
)

# %%
reranker = CrossEncoder("cross-encoder/ms-marco-MiniLM-L-6-v2") # "BAAI/bge-reranker-v2-m3" is a bit slow while testing

# %%
def rerank_with_crossencoder(query, docs, top_k=5, batch_size=16):
    if not docs:
        return []
    pairs = [[query, d.page_content] for d in docs]
    scores = reranker.predict(pairs, batch_size=batch_size) 
    order = np.argsort(scores)[::-1]
    return [docs[i] for i in order[:top_k]]

# %%
def format_docs(docs, max_chars=900):
    blocks = []
    citation_map = {}
    for i, d in enumerate(docs, start=1):
        txt = d.page_content[:max_chars]
        md = d.metadata
        blocks.append(f"[{i}] Source: {md['source']} | chunk={md['chunk_index']} \n{txt}")
        citation_map[i] = {
            "source": md["source"],
            "chunk_index": md["chunk_index"],
            "excerpt": txt
        }
    return "\n\n---\n\n".join(blocks), citation_map


def generate_answer(question, docs):
    context, citation_map = format_docs(docs)
    
    prompt = f"""
You are a factual research assistant. 
Use ONLY the context blocks below to answer. 
Use inline citations like [1][2]. 
If unknown, say "Not answerable from documents."

Context:
{context}

Question: {question}

Answer with citations, then add a "SOURCES" section.
"""
    llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)
    output = llm.invoke(prompt).content
    return output, citation_map

# %%
def answer_query(question: str) -> str:
    initial_docs = retriever.invoke(question)
    top_docs = rerank_with_crossencoder(question, initial_docs, top_k=5)
        
    answer, sources = generate_answer(question, top_docs)
    return answer + json.dumps(sources)

# %%
question = "How is Oracle Cloud Applications (OCA)  performing?"
answer = answer_query(question)
print(answer)
# Out:
# Oracle Cloud Applications (OCA) are positioned as an industry-leading business innovation platform that leverages Oracle Cloud Infrastructure (OCI). The OCA offerings provide a broad suite of modular, next-generation cloud software applications that span all core business functions. This includes solutions like Oracle Fusion Cloud ERP, which aims to improve decision-making and workforce productivity by utilizing a single data and security model with a common user interface [3][4].
#
# The comprehensive and flexible deployment models of OCA are seen as a key factor in Oracle's growth strategy, allowing customers to choose options that best meet their specific business needs. This flexibility is a significant differentiator compared to competitors who may offer fewer options and more restrictive deployment models [2].
#
# Furthermore, Oracle anticipates continued growth in cloud services and license support expenses, driven by customer demand for enhanced data center capacity and the establishment of additional data centers in new geographic locations [4]. This expectation indicates a positive outlook for OCA's performance in the market.
#
# SOURCES:
# [1] oracle.pdf | chunk=267
# [2] oracle.pdf | chunk=250
# [3] oracle.pdf | chunk=268
# [4] oracle.pdf | chunk=238  {"1": {"source": "oracle.pdf", "chunk_index": 267, "excerpt": "engineering, consumer packaged goods, defense and intelligence, educa\u0000on, \ufb01nancial services, government, healthcare, high technology, hospitality, industrial \nmanufacturing, life sciences, media and entertainment, oil and gas, professional services, public safety, restaurant, retail, travel and logis\u0000cs, u\u0000li\u0000es and \nwholesale distribu\u0000on industries, among others.\nOracle Cloud Applica\u0000ons (OCA)\nThe broad spectrum of OCA o\ufb00erings provides customers with a choice of so\u0000ware applica\u0000ons delivered via a cloud-based IT environment that we deploy and \nmanage and that customers purchase by entering into a subscrip\u0000on agreement with us for a stated period. Our OCA o\ufb00erings represent an industry leading"}, "2": {"source": "oracle.pdf", "chunk_index": 250, "excerpt": "how they deploy Oracle applica\u0000ons and infrastructure technologies. We believe that o\ufb00ering customers broad, comprehensive, \ufb02exible and interoperable \ndeployment models for Oracle applica\u0000ons and infrastructure technologies is important to our growth strategy and be\u0000er addresses customer needs rela\u0000ve \nto our compe\u0000tors, many of whom provide fewer o\ufb00erings, more restric\u0000ve deployment models and less \ufb02exibility for customers transi\u0000oning to cloud-based \nIT environments.\nOracle Cloud Applica\u0000ons (OCA) and Oracle Cloud Infrastructure (OCI, collec\u0000vely with OCA, Oracle Cloud Services) o\ufb00erings provide comprehensive and \nintegrated applica\u0000ons and infrastructure services, enabling our customers to choose the best op\u0000on that meets their speci\ufb01c business needs. Oracle Cloud"}, "3": {"source": "oracle.pdf", "chunk_index": 268, "excerpt": "manage and that customers purchase by entering into a subscrip\u0000on agreement with us for a stated period. Our OCA o\ufb00erings represent an industry leading \nbusiness innova\u0000on pla\u0000orm leveraging OCI and include a broad suite of modular, next-genera\u0000on cloud so\u0000ware applica\u0000ons spanning all core business \nfunc\u0000ons, including, among others:\n\u2022 Oracle Fusion Cloud ERP, which is designed to be a complete and integrated ERP solu\u0000on to help organiza\u0000ons improve decision making and \nworkforce produc\u0000vity, and to op\u0000mize back-o\ufb03ce opera\u0000ons by u\u0000lizing a single data and security model with a common user interface; \n\u2022 Oracle Fusion Cloud Enterprise Performance Management (EPM), which is designed to analyze \ufb01nancial performance, drive accurate and agile"}, "4": {"source": "oracle.pdf", "chunk_index": 238, "excerpt": "\u2022 our belief that Oracle Fusion Cloud Enterprise Resource Planning is a strategic suite of applica\u0000ons that is founda\u0000onal to facilita\u0000ng and extrac\u0000ng \nmore business value out of the adop\u0000on of other OCA o\ufb00erings as customers realize the value of a common data model that spans across core \nbusiness applica\u0000ons;\n\u2022 our belief that our OCA o\ufb00erings remove business boundaries between front- and back-o\ufb03ce ac\u0000vi\u0000es;\n\u2022 our expecta\u0000on that current and expected customer demand will require con\u0000nued growth in our cloud services and license support expenses in \norder to increase our exis\u0000ng data center capacity and establish addi\u0000onal data centers in new geographic loca\u0000ons;"}, "5": {"source": "oracle.pdf", "chunk_index": 272, "excerpt": "Customers access OCA o\ufb00erings u\u0000lizing common web browsers via a broad spectrum of devices.\nCustomers, partners and other interested par\u0000es may elect to subscribe to Oracle applica\u0000ons and infrastructure training and cer\u0000\ufb01ca\u0000on programs through \nlearning subscrip\u0000ons o\ufb00ered by Oracle University. Learners generally have unlimited access to course ...

# %% [markdown]
# ## Web search - Tavily implementation

# %%
WEB_KEYWORDS = [r"\blatest\b", r"\btoday\b", r"\bcurrent\b", r"\brecent\b", r"\bbreaking\b"]
RAG_KEYWORDS = [r"\bpolicy\b", r"\binternal\b", r"\bproduct\b", r"\bmanual\b", r"\bknowledge base\b"]

def get_chat_llm(model: str = "gpt-4o-mini", temperature: float = 0.0) -> ChatOpenAI:
    if not OPENAI_API_KEY:
        raise RuntimeError("OPENAI_API_KEY must be set in environment")
    return ChatOpenAI(model=model, temperature=temperature, api_key=OPENAI_API_KEY)

def extract_text(html: str) -> str:
    soup = BeautifulSoup(html, "html.parser")
    for s in soup(["script", "style", "noscript"]):
        s.decompose()
    text = soup.get_text(separator="\n")
    lines = [line.strip() for line in text.splitlines()]
    text = "\n".join([l for l in lines if l])
    return text

# %%
@tool
def finance_web_search(topic: str) -> str:
    """
    Use TavilySearchResults to find articles and investment blogs for a given
    `topic` (e.g., 'NVIDIA Q3 earnings analysis', 'impact of Fed rate hike on tech stocks').
    It fetches the top pages and summarizes them with a Financial Analyst LLM.
    Returns a plain text aggregation of financial summaries.
    """
    if TAVILY_API_KEY == "YOUR_TAVILY_API_KEY" or not TAVILY_API_KEY:
        return "TAVILY_API_KEY not set; cannot run Tavily search. Please set the environment variable."

    query = f"financial analysis and investment insights on {topic}"

    search = TavilySearchResults(k=5, api_key=TAVILY_API_KEY)
    results = search.run(query)
    urls = [r.get("url") for r in results if "url" in r]

    llm = get_chat_llm(model="gpt-4o-mini", temperature=0)

    summaries: List[str] = []
    for url in urls:
        try:
            resp = requests.get(url, headers=HEADERS, timeout=10)
            resp.raise_for_status()
            text = extract_text(resp.text)
            text = text[:12000]

            prompt = [
                SystemMessage(content="You are a sophisticated Financial Analyst and content summarizer. Produce a crisp summary focused on investment takeaways, risks, and financial implications."),
                HumanMessage(content=f"Summarize the following webpage content for financial and investment insights related to '{topic}':\n\n{text}")
            ]
            
            response = llm.invoke(prompt)
            summary = getattr(response, "content", str(response))
            summaries.append(f"Source URL: {url}\nSummary: {summary}\n")
            
        except Exception as e:
            summaries.append(f"Source URL: {url}\nError summarizing page: {e}\n")

    return "\n".join(summaries)

# %% [markdown]
# # Implementation of LangGraph Nodes

# %%
def add_messages(left: list, right: list):
    """Reducer function to correctly append new messages to the list."""
    return left + right

class FinancialAgentState(TypedDict, total=False):
    """
    Represents the state of our financial assistant conversation.
    It combines the conversational history with explicit data fields 
    for multi-step financial analysis.
    """
    messages: Annotated[List[Union[HumanMessage, AIMessage]], add_messages]
    query: str         
    topic: str        
    raw_data: str 
    final_report: str
    route: Literal["web_search", "rag", "llm"]

# %% [markdown]
# ### Refine Query Node - Entry node

# %%
def refine_query_node(state: FinancialAgentState) -> FinancialAgentState:
    node_name = "refine_query"

    messages = state.get("messages", [])
    user_query = ""
    for msg in reversed(messages):
        if msg.type == "human":
            user_query = msg.content
            break

    if not user_query:
        output = {"query": "", "topic": ""}
        log_node(node_name, state, output)
        return output

    llm = get_llm(model="gpt-4o-mini", temperature=0)

    refine_system = (
        "You are a financial reasoning assistant.\n"
        "Refine the user's query so downstream components can understand it.\n"
        "Return ONLY the improved query.\n"
        "Do NOT answer the question.\n"
    )

    resp = llm.invoke([
        {"role": "system", "content": refine_system},
        {"role": "user", "content": f"Refine this financial query: {user_query}"}
    ])

    refined = resp.content.strip()

    topic_system = (
        "Extract the main financial topic from the query in 3–6 words.\n"
        "Return ONLY the topic phrase."
    )

    topic_resp = llm.invoke([
        {"role": "system", "content": topic_system},
        {"role": "user", "content": refined}
    ])

    topic = topic_resp.content.strip()

    output = {
        "query": refined,
        "topic": topic
    }

    log_node(node_name, state, output)
    return output

# %% [markdown]
# ### Router Node

# %%
def build_classifier_llm():
    """
    Returns an LLM used only for routing/classification.
    No tools. Pure prompt → output.
    """
    return get_llm(
        model="gpt-4o-mini",
        temperature=0
    )

# %%
def router_node(state: FinancialAgentState) -> FinancialAgentState:
    node_name = "router"

    query = state.get("query", "").strip()

    if not query:
        output = {"route": "llm"}
        log_node(node_name, state, output)
        return output

    llm = build_classifier_llm()

    resp = llm.invoke([
        {
            "role": "system",
            "content": (
                "Classify the user's financial query into EXACTLY one category:\n"
                "rag has detailes about the company netflix and oracle, for other companies search the web"
                "If its a question about other companies use websearch"
                "If its just about non financial stuffs then use regular llm"
                "- web_search\n- rag\n- llm\nReturn ONLY one token."
            )
        },
        {"role": "user", "content": query}
    ])

    route = resp.content.strip().lower()

    allowed = {"web_search", "rag", "llm"}
    if route not in allowed:
        route = "llm"

    output = {"route": route}
    log_node(node_name, state, output)
    return output

# %% [markdown]
# ### Web search, RAN and general LLM node

# %%
def web_search_node(state: FinancialAgentState) -> FinancialAgentState:
    node_name = "web_search"

    q = state.get("query") or ""
    evidence = finance_web_search.invoke({"topic": q})
    output = {"evidence": evidence}

    log_node(node_name, state, output)
    return output

def rag_node(state: FinancialAgentState) -> FinancialAgentState:
    node_name = "rag"

    q = state.get("query", "")
    evidence = answer_query(q)
    output = {"evidence": evidence}

    log_node(node_name, state, output)
    return output

def llm_node(state: FinancialAgentState) -> FinancialAgentState:
    node_name = "llm_reason"

    q = state.get("query", "")
    llm = get_llm()

    resp = llm.invoke([
        {"role": "system", "content": "Answer concisely."},
        {"role": "user", "content": q}
    ])

    output = {"evidence": resp.content}
    log_node(node_name, state, output)
    return output

# %% [markdown]
# ### Final summarizer node

# %%
def financial_summarizer_node(state: Dict[str, Any]) -> Dict[str, Any]:
    node_name = "summarizer"

    llm = get_llm(model="gpt-4o")

    topic = state.get("topic", state.get("query", "financial topic"))
    raw_data = state.get("raw_data", state.get("evidence", ""))

    system_instruction = (
        "You are a Chief Investment Strategist..."
    )

    user_instruction = f"""
Write a detailed Financial Analysis Report for: {topic}

--- EVIDENCE ---
{raw_data}
"""

    response = llm.invoke([
        {"role": "system", "content": system_instruction},
        {"role": "user", "content": user_instruction}
    ])

    output = {"final_report": response.content}
    log_node(node_name, state, output)
    return output

# %% [markdown]
# ### Logging and Creating the flow

# %%
def log_node(node_name: str, input_state: str, output_state: str):
    print(f"\n\n===== NODE TRIGGERED: {node_name} =====")
    print(f"--- INPUT STATE ---\n{input_state}")
    print(f"--- OUTPUT STATE ---\n{output_state}")
    print("=====================================\n")

# %%
def create_flow():
    """Creates the LangGraph flow for the financial analysis assistant."""
    graph = StateGraph(FinancialAgentState)

    graph.add_node("refine_query", refine_query_node)
    graph.set_entry_point("refine_query")
    
    graph.add_node("router", router_node)
    
    graph.add_node("web_search", web_search_node)
    graph.add_node("rag", rag_node)
    graph.add_node("llm_reason", llm_node)
    
    graph.add_node("summarizer", financial_summarizer_node)

    graph.add_edge("refine_query", "router")
    
    graph.add_conditional_edges(
        "router",
        lambda s: s["route"],
        {
            "web_search": "web_search",
            "rag": "rag",
            "llm": "llm_reason",
        }
    )

    graph.add_edge("web_search", "summarizer")
    graph.add_edge("rag", "summarizer")
    graph.add_edge("llm_reason", "summarizer")

    graph.add_edge("summarizer", END)

    return graph.compile()

# %%
flow = create_flow()

# %% [markdown]
# ## Test Case 1 - Demostrates RAG Route
#
# As you can see in the output section logs
# ===== NODE TRIGGERED: router =====
# --- INPUT STATE ---
# {'messages': [HumanMessage(content='Compare the valuation and recent news for Netflix and Oracle.', additional_kwargs={}, response_metadata={})], 'query': 'Compare the current valuation metrics and recent news developments for Netflix and Oracle.', 'topic': 'Valuation metrics for Netflix and Oracle', 'raw_data': ''}
# --- OUTPUT STATE ---
# {'route': 'rag'}

# %%
input_state = {
    "messages": [
        HumanMessage(content="Compare the valuation and recent news for Netflix and Oracle.")
    ],
    "query": "Compare the valuation and recent news for Netflix and Oracle.",
    "topic": "Netflix vs Oracle Stocks",
    "raw_data": "",
}

result = flow.invoke(input_state)

print("\n===== FINANCIAL REPORT =====\n")
print(result.get("final_report") or result)
# Out:
# ===== NODE TRIGGERED: refine_query =====
# --- INPUT STATE ---
# {'messages': [HumanMessage(content='Compare the valuation and recent news for Netflix and Oracle.', additional_kwargs={}, response_metadata={})], 'query': 'Compare the valuation and recent news for Netflix and Oracle.', 'topic': 'Netflix vs Oracle Stocks', 'raw_data': ''}
# --- OUTPUT STATE ---
# {'query': 'Compare the current valuation metrics and recent news developments for Netflix and Oracle.', 'topic': 'Valuation metrics for Netflix and Oracle'}
# =====================================
#
#
#
# ===== NODE TRIGGERED: router =====
# --- INPUT STATE ---
# {'messages': [HumanMessage(content='Compare the valuation and recent news for Netflix and Oracle.', additional_kwargs={}, response_metadata={})], 'query': 'Compare the current valuation metrics and recent news developments for Netflix and Oracle.', 'topic': 'Valuation metrics for Netflix and Oracle', 'raw_data': ''}
# --- OUTPUT STATE ---
# {'route': 'rag'}
# =====================================
#
#
#
# ===== NODE TRIGGERED: rag =====
# --- INPUT STATE ---
# {'messages': [HumanMessage(content='Compare the valuation and recent news for Netflix and Oracle.', additional_kwargs={}, response_metadata={})], 'query': 'Compare the current valuation metrics and recent news developments for Netflix and Oracle.', 'topic': 'Valuation metrics for Netflix and Oracle', 'raw_data': '', 'route': 'rag'}
# --- OUTPUT STATE ---
# {'evidence': 'Not answerable from documents. \n\nSOURCES:\n[1] Source: Netflix.pdf | chunk=16  \n[2] Source: oracle.pdf | chunk=502  \n[3] Source: Netflix.pdf | chunk=6  \n[4] Source: Netflix.pdf | chunk=19  \n[5] Source: oracle.pdf | chunk=504  {"1": {"source": "Netflix.pdf", "chunk_index": 16, "excerpt": "Table of Contents\\nNETFLIX, INC.\\nConsolidated Balance Sheets\\n(in thousands, except share and par value data)\\nAs of\\n   September 30,2025 December 31,2024\\n(unaudited)\\nAssets\\nCurrent assets:\\nCash and cash equivalents $ 9,287,287 $ 7,804,733 \\nShort-term investments 37,105 1,779,006 \\nOther current assets 3,638,543 3,516,640 \\nTotal current assets 12,962,935 13,100,379 \\nContent assets, net 32,639,879 32,452,462 \\nProperty and equipment, net 1,837,889 1,593,756 \\nOther non-current assets 7,494,132 6,483,777 \\nTotal assets $ 54,934,835 $ 53,630,374 \\nLiabilities and Stockholders\\u2019 Equity\\nCurrent liabilities:\\nCurrent content liabilities $ 4,102,640 $ 4,393,681 \\nAccounts payable 793,233 899,909 \\nAccrued expenses and other liabilities 3,111,311 2,156,544 \\nDeferred revenue 1,724,675 1,520,813"}, "2": {"source": "oracle.pdf", "chunk_index": 502, "excerpt": "COMPARISON OF 5 YEAR CUMULATIVE TOTAL RETURN*\\nAmong Oracle Corpora\\u0000on, the S&P 500 Index and the Dow Jones U.S. Technology Total Return Index\\n \\n*$100 INVESTED ON MAY 31, 2020 IN STOCK OR\\nINDEX-INCLUDING REINVESTMENT OF DIVIDENDS\\n \\n  5/20   5/21   5/22   5/23   5/24   5/25  \\nOracle Corpora\\u0000on   100.0   148.8   138.0   206.8   232.0   331.5 S&P 500 Index   100.0   140.3   139.9   144.0   184.6   209.5 Dow Jones U.S. Technology Total Return Index   100.0   148.0   142.0   168.9   236.8   272.4 \\n \\nItem 6. [Reserved]"}, "3": {"source": "Netflix.pdf", "chunk_index": 6, "excerpt": "Table of Contents\\nNETFLIX, INC.\\nConsolidated Statements of Operations\\n(unaudited)\\n(in thousands, except per share data)\\nThree Months Ended Nine Months Ended\\nSeptember 30,2025 September 30,2024 September 30,2025 September 30,2024\\nRevenues $ 11,510,307 $ 9,824,703 $ 33,132,274 $ 28,754,453 \\nCost of revenues 6,164,250 5,119,884 16,752,708 15,271,100 \\nSales and marketing 786,295 642,926 2,187,930 1,941,350 \\nTechnology and development 853,584 735,063 2,501,090 2,148,790 \\nGeneral and administrative 457,931 417,353 1,320,606 1,248,365 \\nOperating income 3,248,247 2,909,477 10,369,940 8,144,848 \\nOther income (expense):\\nInterest expense (175,294) (184,830) (542,115) (526,130)\\nInterest and other income (expense) 36,457 (21,693) 126,986 212,671"}, "4": {"source": "Netflix.pdf", "chunk_index": 19, "excerpt": "Table of Contents\\nNETFLIX, INC.\\nConsolidated Statements of Stockholders\\u2019 Equity\\n(unaudited)\\n(in thousands)\\nThree Months Ended Nine Months Ended\\n September 30,2025 September 30,2024 September 30,2025 September 30,2024\\nTotal stockholders\' equity, beginning balances $ 24,951,899 $ 22,112,693 $ 24,743,567 $ 20,588,313 \\nCommon stock and additional paid-in capital:\\nBeginning balances $ 6,932,828 $ 5,680,061 $ 6,252,126 $ 5,145,172 \\nIssuance of common stock 66,511 142,192 594,374 531,970 \\n Stock-based compensation expense 80,986 65,650 233,825 210,761 \\nEnding balances $ 7,080,325 $ 5,887,903 $ 7,080,325 $ 5,887,903 \\nTreasury stock:\\nBeginning balances $ (18,392,942) $ (10,547,055) $ (13,171,638) $ (6,922,200)"}, "5": {"source": "oracle.pdf", "chunk_index": 504, "excerpt": "2025 compared to \\ufb01scal 2024. A discussion regarding our \\ufb01nancial condi\\u0000on and results of opera\\u0000ons for \\ufb01scal 2024 compared to \\ufb01scal 2023 can be found in \\nManagement\\u2019s Discussion and Analysis of Financial Condi\\u0000on and Results of Opera\\u0000ons in Part II, Item 7 of our Annual Report on Form 10-K for the \\ufb01scal year \\nended May 31, 2024, as \\ufb01led with the SEC on June 20, 2024, which is available free of charge on the SEC\\u2019s website at www.sec.gov and on our Inv ...
# =====================================
#
#
#
# ===== NODE TRIGGERED: summarizer =====
# --- INPUT STATE ---
# {'messages': [HumanMessage(content='Compare the valuation and recent news for Netflix and Oracle.', additional_kwargs={}, response_metadata={})], 'query': 'Compare the current valuation metrics and recent news developments for Netflix and Oracle.', 'topic': 'Valuation metrics for Netflix and Oracle', 'raw_data': '', 'route': 'rag'}
# --- OUTPUT STATE ---
# {'final_report': "# Financial Analysis Report: Valuation Metrics for Netflix and Oracle\n\n## Executive Summary\n\nThis report provides a detailed analysis of the valuation metrics for Netflix, Inc. (NASDAQ: NFLX) and Oracle Corporation (NYSE: ORCL). Both companies operate in distinct sectors, with Netflix being a leading player in the streaming entertainment industry and Oracle a major entity in the enterprise software and cloud computing space. This analysis will cover key valuation metrics, including Price-to-Earnings (P/E) ratio, Price-to-Sales (P/S) ratio, Price-to-Book (P/B) ratio, and Enterprise Value to EBITDA (EV/EBITDA), among others. The report aims to provide insights into the relative valuation of these companies and their potential investment attractiveness.\n\n## Company Overview\n\n### Netflix, Inc. (NFLX)\n- **Industry**: Streaming Entertainment\n- **Market Capitalization**: Approximately $200 billion (as of the latest data)\n- **Business Model**: Subscription-based streaming service offering a wide range of TV shows, movies, and original content.\n\n### Oracle Corporation (ORCL)\n- **Industry**: Enterprise Software and Cloud Computing\n- **Market Capitalization**: Approximately $300 billion (as of the latest data)\n- **Business Model**: Provides software, cloud solutions, and hardware products and services to businesses worldwide.\n\n## Valuation Metrics\n\n### 1. Price-to-Earnings (P/E) Ratio\n- **Netflix**: The P/E ratio for Netflix is typically higher than the industry average, reflecting its growth potential and market leadership in streaming. As of the latest data, Netflix's P/E ratio is around 35x.\n- **Oracle**: Oracle's P/E ratio is generally lower than Netflix's, reflecting its more mature business model and stable cash flows. The current P/E ratio for Oracle is approximately 20x.\n\n### 2. Price-to-Sales (P/S) Ratio\n- **Netflix**: With a P/S ratio of about 6x, Netflix's valuation reflects its strong revenue growth and market position.\n- **Oracle**: Oracle's P/S ratio is around 5x, indicating a more conservative valuation compared to high-growth tech companies.\n\n### 3. Price-to-Book (P/B) Ratio\n- **Netflix**: The P/B ratio for Netflix is relatively high, at approximately 15x, due to its intangible assets and brand value.\n- **Oracle**: Oracle's P/B ratio is around 8x, reflecting its substantial tangible assets and established market presence.\n\n### 4. Enterprise Value to EBITDA (EV/EBITDA)\n- **Netflix**: The EV/EBITDA ratio for Netflix is approximately 25x, indicating a premium valuation based on its earnings before interest, taxes, depreciation, and amortization.\n- **Oracle**: Oracle's EV/EBITDA ratio is about 15x, suggesting a more moderate valuation compared to Netflix.\n\n## Comparative Analysis\n\n- **Growth vs. Stability**: Netflix's higher valuation metrics, such as P/E and EV/EBITDA, reflect its growth-oriented business model and potential for future expansion. In contrast, Oracle's lower valuation metrics indicate a more stable, income-generating business with less volatility.\n- **Market Position**: Netflix's leadership in the streaming industry justifies its premium valuation, while Oracle's strong position in enterprise software and cloud computing supports its steady valuation.\n- **Risk Factors**: Investors in Netflix face higher risk due to market competition and content costs, whereas Oracle's risks are more related to technological shifts and competition in the cloud space.\n\n## Conclusion\n\nBoth Netflix and Oracle present unique investment opportunities. Netflix offers high growth potential with a premium valuation, suitable for investors seeking exposure to the dynamic streaming industry. Oracle, with its stable cash flows and moderate valuation, appeals to investors looking for a more conservative investment in the tech sector. Investors should consider their risk tolerance, investment horizon, and market outlook when evaluating these companies.\n\n## Recommendations\n\n ...
# =====================================
#
#
# ===== FINANCIAL REPORT =====
#
# # Financial Analysis Report: Valuation Metrics for Netflix and Oracle
#
# ## Executive Summary
#
# This report provides a detailed analysis of the valuation metrics for Netflix, Inc. (NASDAQ: NFLX) and Oracle Corporation (NYSE: ORCL). Both companies operate in distinct sectors, with Netflix being a leading player in the streaming entertainment industry and Oracle a major entity in the enterprise software and cloud computing space. This analysis will cover key valuation metrics, including Price-to-Earnings (P/E) ratio, Price-to-Sales (P/S) ratio, Price-to-Book (P/B) ratio, and Enterprise Value to EBITDA (EV/EBITDA), among others. The report aims to provide insights into the relative valuation of these companies and their potential investment attractiveness.
#
# ## Company Overview
#
# ### Netflix, Inc. (NFLX)
# - **Industry**: Streaming Entertainment
# - **Market Capitalization**: Approximately $200 billion (as of the latest data)
# - **Business Model**: Subscription-based streaming service offering a wide range of TV shows, movies, and original content.
#
# ### Oracle Corporation (ORCL)
# - **Industry**: Enterprise Software and Cloud Computing
# - **Market Capitalization**: Approximately $300 billion (as of the latest data)
# - **Business Model**: Provides software, cloud solutions, and hardware products and services to businesses worldwide.
#
# ## Valuation Metrics
#
# ### 1. Price-to-Earnings (P/E) Ratio
# - **Netflix**: The P/E ratio for Netflix is typically higher than the industry average, reflecting its growth potential and market leadership in streaming. As of the latest data, Netflix's P/E ratio is around 35x.
# - **Oracle**: Oracle's P/E ratio is generally lower than Netflix's, reflecting its more mature business model and stable cash flows. The current P/E ratio for Oracle is approximately 20x.
#
# ### 2. Price-to-Sales (P/S) Ratio
# - **Netflix**: With a P/S ratio of about 6x, Netflix's valuation reflects its strong revenue growth and market position.
# - **Oracle**: Oracle's P/S ratio is around 5x, indicating a more conservative valuation compared to high-growth tech companies.
#
# ### 3. Price-to-Book (P/B) Ratio
# - **Netflix**: The P/B ratio for Netflix is relatively high, at approximately 15x, due to its intangible assets and brand value.
# - **Oracle**: Oracle's P/B ratio is around 8x, reflecting its substantial tangible assets and established market presence.
#
# ### 4. Enterprise Value to EBITDA (EV/EBITDA)
# - **Netflix**: The EV/EBITDA ratio for Netflix is approximately 25x, indicating a premium valuation based on its earnings before interest, taxes, depreciation, and amortization.
# - **Oracle**: Oracle's EV/EBITDA ratio is about 15x, suggesting a more moderate valuation compared to Netflix.
#
# ## Comparative Analysis
#
# - **Growth vs. Stability**: Netflix's higher valuation metrics, such as P/E and EV/EBITDA, reflect its growth-oriented business model and potential for future expansion. In contrast, Oracle's lower valuation metrics indicate a more stable, income-generating business with less volatility.
# - **Market Position**: Netflix's leadership in the streaming industry justifies its premium valuation, while Oracle's strong position in enterprise software and cloud computing supports its steady valuation.
# - **Risk Factors**: Investors in Netflix face higher risk due to market competition and content costs, whereas Oracle's risks are more related to technological shifts and competition in the cloud space.
#
# ## Conclusion
#
# Both Netflix and Oracle present unique investment opportunities. Netflix offers high growth potential with a premium valuation, suitable for investors seeking exposure to the dynamic streaming industry. Oracle, with its stable cash flows and moderate valuation, appeals to investors looking for a more conservative investment in the tech sector. Investors should consider their risk tolerance, investment horizon, and market outlook when evaluating these companies.
#
# ## Recommendations
#
# - **For Growth Investors**: Consider Netflix for its potential to capitalize on the expanding streaming market, despite its higher valuation metrics.
# - **For Value and Income Investors**: Oracle may be a more suitable choice due to its stable earnings, lower valuation, and potential for dividend income.
#
# ---
#
# This report is based on the latest available data and market conditions. Investors should conduct further research and consider market developments before making investment decisions.

# %% [markdown]
# ## Test Case 2 - Demostrates Websearch Route
#
# As you can see in the output section logs  ===== NODE TRIGGERED: router =====
# --- INPUT STATE ---
# {'messages': [HumanMessage(content='Compare the valuation and most recent news for Google and Tesla.', additional_kwargs={}, response_metadata={})], 'query': 'Compare the current valuation metrics and latest news updates for Google and Tesla.', 'topic': 'Valuation metrics for Google and Tesla', 'raw_data': ''}
# --- OUTPUT STATE ---
# {'route': 'web_search'}

# %%
input_state = {
    "messages": [
        HumanMessage(content="Compare the valuation and most recent news for Google and Tesla.")
    ],
    "query": "Compare the valuation and recent news for Google and Tesla.",
    "topic": "Google vs Tesla Stocks",
    "raw_data": "",
}

result = flow.invoke(input_state)

print("\n===== FINANCIAL REPORT =====\n")
print(result.get("final_report") or result)
# Out:
# ===== NODE TRIGGERED: refine_query =====
# --- INPUT STATE ---
# {'messages': [HumanMessage(content='Compare the valuation and most recent news for Google and Tesla.', additional_kwargs={}, response_metadata={})], 'query': 'Compare the valuation and recent news for Google and Tesla.', 'topic': 'Google vs Tesla Stocks', 'raw_data': ''}
# --- OUTPUT STATE ---
# {'query': 'Compare the current valuation metrics and latest news updates for Google and Tesla.', 'topic': 'Valuation metrics for Google and Tesla'}
# =====================================
#
#
#
# ===== NODE TRIGGERED: router =====
# --- INPUT STATE ---
# {'messages': [HumanMessage(content='Compare the valuation and most recent news for Google and Tesla.', additional_kwargs={}, response_metadata={})], 'query': 'Compare the current valuation metrics and latest news updates for Google and Tesla.', 'topic': 'Valuation metrics for Google and Tesla', 'raw_data': ''}
# --- OUTPUT STATE ---
# {'route': 'web_search'}
# =====================================
#
#
#
# ===== NODE TRIGGERED: web_search =====
# --- INPUT STATE ---
# {'messages': [HumanMessage(content='Compare the valuation and most recent news for Google and Tesla.', additional_kwargs={}, response_metadata={})], 'query': 'Compare the current valuation metrics and latest news updates for Google and Tesla.', 'topic': 'Valuation metrics for Google and Tesla', 'raw_data': '', 'route': 'web_search'}
# --- OUTPUT STATE ---
# {'evidence': "Source URL: https://tickeron.com/blogs/goog-ibm-and-tsla-in-2025-stock-growth-comparison-performance-chart-and-earnings-forecast-11387/\nSummary: ### Investment Summary: Google (GOOG), Tesla (TSLA), and IBM (IBM) as of July 2025\n\n#### Current Valuation Metrics:\n- **Alphabet Inc. (GOOG)**: \n  - Stock Price: $191.15\n  - Market Cap: $1.94 trillion\n  - FA Score: 3 green, 2 red (undervalued with strong fundamentals)\n  - Weekly Growth: 4.56%\n  - Expected EPS: $2.17 (22.78% decline YoY)\n\n- **Tesla, Inc. (TSLA)**: \n  - Stock Price: $328.49\n  - Market Cap: $559.85 billion\n  - FA Score: 1 green, 4 red (overvalued with high P/E ratio of 40.73)\n  - Weekly Growth: 3.66%\n  - Expected EPS: $0.40 (48.89% increase YoY)\n\n- **International Business Machines (IBM)**: \n  - Stock Price: $284.71\n  - Market Cap: $264.61 billion\n  - FA Score: 4 green, 1 red (most undervalued)\n  - Weekly Growth: 0.32%\n  - Expected EPS: $2.65 (65.63% increase YoY)\n\n#### Investment Takeaways:\n1. **Alphabet (GOOG)** is positioned as a strong long-term investment due to its diversified revenue streams and AI investments, despite facing short-term challenges in advertising revenue.\n2. **IBM** presents a stable investment opportunity with a solid dividend yield and a focus on hybrid cloud and AI, making it attractive for conservative investors.\n3. **Tesla (TSLA)**, while showing strong short-term growth, carries higher risks due to its overvaluation and competitive pressures in the EV market. It may appeal to risk-tolerant investors looking for high-reward potential.\n\n#### Risks:\n- **Alphabet** faces macroeconomic uncertainties impacting advertising revenue and increased competition in cloud services.\n- **Tesla** is under scrutiny for tariff impacts and declining demand for certain models, which could affect profit margins.\n- **IBM** may experience slower growth compared to its tech peers, limiting upside potential.\n\n#### Financial Implications:\n- The tech sector is experiencing robust growth, with Alphabet and Tesla capitalizing on industry momentum, while IBM offers stability amidst a more modest growth environment.\n- Investors should consider the volatility of Tesla against the steadiness of IBM and the growth potential of Alphabet when constructing their portfolios.\n- The use of AI-driven trading tools and inverse ETFs (like TECS) can provide strategic hedging opportunities against potential downturns in tech stocks.\n\n### Conclusion:\nInvestors should weigh the growth potential and risks associated with each company, aligning their investment choices with their risk tolerance and market outlook. Alphabet and IBM appear to be safer bets for long-term growth, while Tesla offers a high-risk, high-reward scenario.\n\nSource URL: https://www.morningstar.com/stocks/tesla-stock-vs-alphabet-stock-which-is-better-buy-today\nSummary: **Investment Summary: Google vs. Tesla**\n\n**Valuation Metrics:**\n- **Google (Alphabet Inc.)**: Currently trading at a P/E ratio of around 25, indicating a moderate valuation relative to its earnings. The company shows strong revenue growth driven by its advertising business and cloud services.\n- **Tesla**: Exhibits a higher P/E ratio, approximately 70, reflecting aggressive growth expectations. The valuation is supported by increasing vehicle deliveries and expansion into energy products.\n\n**Latest News Updates:**\n- **Google**: Recent developments include advancements in AI technology and regulatory scrutiny regarding data privacy. These factors could impact future growth and operational costs.\n- **Tesla**: The company is facing challenges with supply chain issues and competition in the EV market. However, it continues to innovate with new models and battery technology, which may enhance its market position.\n\n**Investment Takeaways:**\n- **Google**: Appears to be a stable investment with solid fundamentals and growth potential, particularly in cloud computing and AI. The moderate valuation ...
# =====================================
#
#
#
# ===== NODE TRIGGERED: summarizer =====
# --- INPUT STATE ---
# {'messages': [HumanMessage(content='Compare the valuation and most recent news for Google and Tesla.', additional_kwargs={}, response_metadata={})], 'query': 'Compare the current valuation metrics and latest news updates for Google and Tesla.', 'topic': 'Valuation metrics for Google and Tesla', 'raw_data': '', 'route': 'web_search'}
# --- OUTPUT STATE ---
# {'final_report': "# Financial Analysis Report: Valuation Metrics for Google and Tesla\n\n## Executive Summary\n\nThis report provides a comprehensive analysis of the valuation metrics for two major companies: Alphabet Inc. (Google) and Tesla, Inc. The analysis includes an examination of key financial ratios, market performance, and growth prospects. The objective is to provide insights into the current valuation of these companies and their potential for future growth.\n\n## Company Overview\n\n### Alphabet Inc. (Google)\nAlphabet Inc., the parent company of Google, is a global technology leader specializing in internet services and products. Its core businesses include search, advertising, cloud computing, and hardware. Alphabet's diverse portfolio and strong market position make it a significant player in the tech industry.\n\n### Tesla, Inc.\nTesla, Inc. is a leading electric vehicle (EV) manufacturer and clean energy company. Tesla's product line includes electric cars, battery energy storage, and solar products. The company is known for its innovation and has a strong presence in the rapidly growing EV market.\n\n## Valuation Metrics\n\n### Alphabet Inc. (Google)\n\n1. **Price-to-Earnings (P/E) Ratio**\n   - Alphabet's P/E ratio is a critical indicator of its valuation. As of the latest data, Alphabet's P/E ratio is approximately 25. This suggests that investors are willing to pay $25 for every $1 of earnings, reflecting confidence in the company's growth prospects.\n\n2. **Price-to-Sales (P/S) Ratio**\n   - The P/S ratio for Alphabet is around 6. This indicates that investors are paying $6 for every $1 of sales, which is relatively high, reflecting the company's strong revenue generation capabilities.\n\n3. **Price-to-Book (P/B) Ratio**\n   - Alphabet's P/B ratio is approximately 5. This suggests that the market values the company at five times its book value, indicating strong investor confidence in its asset base and future profitability.\n\n4. **Enterprise Value to EBITDA (EV/EBITDA)**\n   - The EV/EBITDA ratio for Alphabet is about 18. This metric indicates the company's valuation relative to its earnings before interest, taxes, depreciation, and amortization, suggesting a healthy operating performance.\n\n### Tesla, Inc.\n\n1. **Price-to-Earnings (P/E) Ratio**\n   - Tesla's P/E ratio is significantly higher than the industry average, currently around 70. This high ratio reflects investor optimism about Tesla's future growth and market expansion.\n\n2. **Price-to-Sales (P/S) Ratio**\n   - Tesla's P/S ratio is approximately 10, indicating that investors are paying a premium for each dollar of sales, driven by expectations of continued revenue growth.\n\n3. **Price-to-Book (P/B) Ratio**\n   - The P/B ratio for Tesla is around 20, suggesting that the market values the company at twenty times its book value. This high ratio reflects the market's confidence in Tesla's innovative capabilities and future potential.\n\n4. **Enterprise Value to EBITDA (EV/EBITDA)**\n   - Tesla's EV/EBITDA ratio is approximately 40, indicating a high valuation relative to its operating earnings. This reflects the market's expectations of strong future earnings growth.\n\n## Market Performance and Growth Prospects\n\n### Alphabet Inc. (Google)\n- **Market Performance**: Alphabet has shown consistent revenue growth driven by its advertising business and cloud services. The company's strong cash flow and robust balance sheet position it well for future investments and acquisitions.\n- **Growth Prospects**: Alphabet's growth prospects are supported by its leadership in digital advertising, expansion in cloud computing, and investments in artificial intelligence and other emerging technologies.\n\n### Tesla, Inc.\n- **Market Performance**: Tesla has experienced rapid growth in vehicle deliveries and revenue, driven by increasing demand for electric vehicles. The company's focus on innovation and expansion into new markets supports its strong market ...
# =====================================
#
#
# ===== FINANCIAL REPORT =====
#
# # Financial Analysis Report: Valuation Metrics for Google and Tesla
#
# ## Executive Summary
#
# This report provides a comprehensive analysis of the valuation metrics for two major companies: Alphabet Inc. (Google) and Tesla, Inc. The analysis includes an examination of key financial ratios, market performance, and growth prospects. The objective is to provide insights into the current valuation of these companies and their potential for future growth.
#
# ## Company Overview
#
# ### Alphabet Inc. (Google)
# Alphabet Inc., the parent company of Google, is a global technology leader specializing in internet services and products. Its core businesses include search, advertising, cloud computing, and hardware. Alphabet's diverse portfolio and strong market position make it a significant player in the tech industry.
#
# ### Tesla, Inc.
# Tesla, Inc. is a leading electric vehicle (EV) manufacturer and clean energy company. Tesla's product line includes electric cars, battery energy storage, and solar products. The company is known for its innovation and has a strong presence in the rapidly growing EV market.
#
# ## Valuation Metrics
#
# ### Alphabet Inc. (Google)
#
# 1. **Price-to-Earnings (P/E) Ratio**
#    - Alphabet's P/E ratio is a critical indicator of its valuation. As of the latest data, Alphabet's P/E ratio is approximately 25. This suggests that investors are willing to pay $25 for every $1 of earnings, reflecting confidence in the company's growth prospects.
#
# 2. **Price-to-Sales (P/S) Ratio**
#    - The P/S ratio for Alphabet is around 6. This indicates that investors are paying $6 for every $1 of sales, which is relatively high, reflecting the company's strong revenue generation capabilities.
#
# 3. **Price-to-Book (P/B) Ratio**
#    - Alphabet's P/B ratio is approximately 5. This suggests that the market values the company at five times its book value, indicating strong investor confidence in its asset base and future profitability.
#
# 4. **Enterprise Value to EBITDA (EV/EBITDA)**
#    - The EV/EBITDA ratio for Alphabet is about 18. This metric indicates the company's valuation relative to its earnings before interest, taxes, depreciation, and amortization, suggesting a healthy operating performance.
#
# ### Tesla, Inc.
#
# 1. **Price-to-Earnings (P/E) Ratio**
#    - Tesla's P/E ratio is significantly higher than the industry average, currently around 70. This high ratio reflects investor optimism about Tesla's future growth and market expansion.
#
# 2. **Price-to-Sales (P/S) Ratio**
#    - Tesla's P/S ratio is approximately 10, indicating that investors are paying a premium for each dollar of sales, driven by expectations of continued revenue growth.
#
# 3. **Price-to-Book (P/B) Ratio**
#    - The P/B ratio for Tesla is around 20, suggesting that the market values the company at twenty times its book value. This high ratio reflects the market's confidence in Tesla's innovative capabilities and future potential.
#
# 4. **Enterprise Value to EBITDA (EV/EBITDA)**
#    - Tesla's EV/EBITDA ratio is approximately 40, indicating a high valuation relative to its operating earnings. This reflects the market's expectations of strong future earnings growth.
#
# ## Market Performance and Growth Prospects
#
# ### Alphabet Inc. (Google)
# - **Market Performance**: Alphabet has shown consistent revenue growth driven by its advertising business and cloud services. The company's strong cash flow and robust balance sheet position it well for future investments and acquisitions.
# - **Growth Prospects**: Alphabet's growth prospects are supported by its leadership in digital advertising, expansion in cloud computing, and investments in artificial intelligence and other emerging technologies.
#
# ### Tesla, Inc.
# - **Market Performance**: Tesla has experienced rapid growth in vehicle deliveries and revenue, driven by increasing demand for electric vehicles. The company's focus on innovation and expansion into new markets supports its strong market performance.
# - **Growth Prospects**: Tesla's growth prospects are bolstered by its leadership in the EV market, expansion of production capacity, and development of new technologies such as autonomous driving and energy storage solutions.
#
# ## Conclusion
#
# Both Alphabet Inc. and Tesla, Inc. exhibit strong valuation metrics, reflecting investor confidence in their growth potential. Alphabet's valuation is supported by its dominant position in digital advertising and cloud services, while Tesla's high valuation is driven by its leadership in the electric vehicle market and innovative capabilities. Investors should consider these factors, along with market conditions and individual risk tolerance, when evaluating investment opportunities in these companies.
#
# ## Recommendations
#
# - **Alphabet Inc. (Google)**: Consider as a stable investment with strong growth potential in digital advertising and cloud services.
# - **Tesla, Inc.**: Suitable for investors seeking high growth potential in the electric vehicle and clean energy sectors, with a willingness to accept higher volatility.
#
# ---
#
# This report is based on the latest available data and market conditions. Investors should conduct further research and consider their financial objectives before making investment decisions.

# %% [markdown]
# ## Test Case 3 - Demostrates General LLM Route
#
# As you can see in the ouput section logs
# ===== NODE TRIGGERED: router =====
# --- INPUT STATE ---
# {'messages': [HumanMessage(content='How to decide which stocks to invest in?', additional_kwargs={}, response_metadata={})], 'query': 'What criteria should I use to choose stocks for investment?', 'topic': 'Stock selection criteria for investment', 'raw_data': ''}
# --- OUTPUT STATE ---
# {'route': 'llm'}

# %%
input_state = {
    "messages": [
        HumanMessage(content="How to decide which stocks to invest in?")
    ],
    "query": "How to decide which stocks to invest in?",
    "topic": "General investment strategies",
    "raw_data": "",
}

result = flow.invoke(input_state)

print("\n===== FINANCIAL REPORT =====\n")
print(result.get("final_report") or result)
# Out:
# ===== NODE TRIGGERED: refine_query =====
# --- INPUT STATE ---
# {'messages': [HumanMessage(content='How to decide which stocks to invest in?', additional_kwargs={}, response_metadata={})], 'query': 'How to decide which stocks to invest in?', 'topic': 'General investment strategies', 'raw_data': ''}
# --- OUTPUT STATE ---
# {'query': 'What criteria should I use to choose stocks for investment?', 'topic': 'Stock selection criteria for investment'}
# =====================================
#
#
#
# ===== NODE TRIGGERED: router =====
# --- INPUT STATE ---
# {'messages': [HumanMessage(content='How to decide which stocks to invest in?', additional_kwargs={}, response_metadata={})], 'query': 'What criteria should I use to choose stocks for investment?', 'topic': 'Stock selection criteria for investment', 'raw_data': ''}
# --- OUTPUT STATE ---
# {'route': 'llm'}
# =====================================
#
#
#
# ===== NODE TRIGGERED: llm_reason =====
# --- INPUT STATE ---
# {'messages': [HumanMessage(content='How to decide which stocks to invest in?', additional_kwargs={}, response_metadata={})], 'query': 'What criteria should I use to choose stocks for investment?', 'topic': 'Stock selection criteria for investment', 'raw_data': '', 'route': 'llm'}
# --- OUTPUT STATE ---
# {'evidence': "When choosing stocks for investment, consider the following criteria:\n\n1. **Fundamental Analysis**:\n   - **Earnings Growth**: Look for companies with consistent revenue and earnings growth.\n   - **Valuation Ratios**: Assess P/E, P/B, and P/S ratios to determine if a stock is undervalued.\n   - **Dividend Yield**: Consider companies that pay dividends for income stability.\n\n2. **Financial Health**:\n   - **Debt Levels**: Evaluate debt-to-equity ratio and interest coverage.\n   - **Cash Flow**: Analyze operating cash flow and free cash flow.\n\n3. **Market Position**:\n   - **Competitive Advantage**: Identify companies with strong market positions or unique products.\n   - **Industry Trends**: Consider sectors with growth potential.\n\n4. **Management Quality**:\n   - **Leadership Track Record**: Research the management team's experience and performance history.\n\n5. **Technical Analysis** (if applicable):\n   - **Price Trends**: Look at historical price movements and patterns.\n   - **Volume Trends**: Analyze trading volume for signs of investor interest.\n\n6. **Economic Indicators**:\n   - **Market Conditions**: Be aware of macroeconomic factors that could impact stock performance.\n\n7. **Risk Tolerance**:\n   - **Volatility**: Assess the stock's historical volatility and your own risk appetite.\n\n8. **Diversification**:\n   - **Portfolio Balance**: Ensure your stock choices contribute to a well-diversified portfolio.\n\nBy combining these criteria, you can make more informed investment decisions."}
# =====================================
#
#
#
# ===== NODE TRIGGERED: summarizer =====
# --- INPUT STATE ---
# {'messages': [HumanMessage(content='How to decide which stocks to invest in?', additional_kwargs={}, response_metadata={})], 'query': 'What criteria should I use to choose stocks for investment?', 'topic': 'Stock selection criteria for investment', 'raw_data': '', 'route': 'llm'}
# --- OUTPUT STATE ---
# {'final_report': "**Financial Analysis Report: Stock Selection Criteria for Investment**\n\n**Executive Summary:**\n\nThis report outlines a comprehensive framework for selecting stocks for investment purposes. The criteria are designed to identify stocks that offer the potential for strong returns while managing risk effectively. The selection process is grounded in both quantitative and qualitative analysis, ensuring a holistic approach to stock evaluation.\n\n**1. Quantitative Criteria:**\n\n1.1 **Financial Health:**\n   - **Revenue Growth:** Consistent revenue growth over the past 3-5 years indicates a company's ability to expand its market presence and increase sales.\n   - **Earnings Per Share (EPS) Growth:** A steady increase in EPS suggests profitability and efficient management.\n   - **Debt-to-Equity Ratio:** A lower ratio is preferred, indicating that a company is not overly reliant on debt to finance its operations.\n   - **Current Ratio:** A ratio above 1 indicates that a company has more current assets than current liabilities, suggesting good short-term financial health.\n\n1.2 **Valuation Metrics:**\n   - **Price-to-Earnings (P/E) Ratio:** A lower P/E compared to industry peers may indicate undervaluation, while a higher P/E could suggest growth potential.\n   - **Price-to-Book (P/B) Ratio:** This helps assess whether a stock is undervalued or overvalued relative to its book value.\n   - **Dividend Yield:** For income-focused investors, a higher dividend yield can be attractive, provided it is sustainable.\n\n1.3 **Profitability Ratios:**\n   - **Return on Equity (ROE):** A higher ROE indicates efficient use of shareholders' equity to generate profits.\n   - **Net Profit Margin:** A higher margin suggests better control over costs and pricing power.\n\n**2. Qualitative Criteria:**\n\n2.1 **Management Quality:**\n   - **Leadership Track Record:** Evaluate the experience and past performance of the executive team.\n   - **Corporate Governance:** Strong governance practices can mitigate risks and align management's interests with those of shareholders.\n\n2.2 **Industry Position:**\n   - **Market Share:** Companies with a significant market share are often more resilient to competitive pressures.\n   - **Competitive Advantage:** Assess the company's unique strengths, such as brand reputation, patents, or proprietary technology.\n\n2.3 **Growth Potential:**\n   - **Innovation and R&D:** Companies investing in research and development may have better long-term growth prospects.\n   - **Market Trends:** Align investments with favorable industry trends, such as technological advancements or demographic shifts.\n\n**3. Risk Assessment:**\n\n3.1 **Volatility:**\n   - **Beta:** A measure of a stock's volatility relative to the market. A beta less than 1 indicates lower volatility, while a beta greater than 1 suggests higher volatility.\n\n3.2 **Economic and Political Risks:**\n   - **Geopolitical Exposure:** Consider the impact of political instability or regulatory changes on the company's operations.\n   - **Economic Sensitivity:** Evaluate how economic cycles affect the company's performance.\n\n**4. ESG Considerations:**\n\n4.1 **Environmental, Social, and Governance (ESG) Factors:**\n   - **Sustainability Practices:** Companies with strong ESG practices may be better positioned for long-term success.\n   - **Social Responsibility:** Evaluate the company's impact on society and its commitment to ethical practices.\n\n**Conclusion:**\n\nThe stock selection criteria outlined in this report provide a robust framework for identifying investment opportunities that balance potential returns with risk management. By integrating both quantitative and qualitative factors, investors can make informed decisions that align with their financial goals and risk tolerance. Regular review and adaptation of these criteria are essential to respond to changing market conditions and emerging trends.\n\n**Recommendations:**\n\n- Conduct r ...
# =====================================
#
#
# ===== FINANCIAL REPORT =====
#
# **Financial Analysis Report: Stock Selection Criteria for Investment**
#
# **Executive Summary:**
#
# This report outlines a comprehensive framework for selecting stocks for investment purposes. The criteria are designed to identify stocks that offer the potential for strong returns while managing risk effectively. The selection process is grounded in both quantitative and qualitative analysis, ensuring a holistic approach to stock evaluation.
#
# **1. Quantitative Criteria:**
#
# 1.1 **Financial Health:**
#    - **Revenue Growth:** Consistent revenue growth over the past 3-5 years indicates a company's ability to expand its market presence and increase sales.
#    - **Earnings Per Share (EPS) Growth:** A steady increase in EPS suggests profitability and efficient management.
#    - **Debt-to-Equity Ratio:** A lower ratio is preferred, indicating that a company is not overly reliant on debt to finance its operations.
#    - **Current Ratio:** A ratio above 1 indicates that a company has more current assets than current liabilities, suggesting good short-term financial health.
#
# 1.2 **Valuation Metrics:**
#    - **Price-to-Earnings (P/E) Ratio:** A lower P/E compared to industry peers may indicate undervaluation, while a higher P/E could suggest growth potential.
#    - **Price-to-Book (P/B) Ratio:** This helps assess whether a stock is undervalued or overvalued relative to its book value.
#    - **Dividend Yield:** For income-focused investors, a higher dividend yield can be attractive, provided it is sustainable.
#
# 1.3 **Profitability Ratios:**
#    - **Return on Equity (ROE):** A higher ROE indicates efficient use of shareholders' equity to generate profits.
#    - **Net Profit Margin:** A higher margin suggests better control over costs and pricing power.
#
# **2. Qualitative Criteria:**
#
# 2.1 **Management Quality:**
#    - **Leadership Track Record:** Evaluate the experience and past performance of the executive team.
#    - **Corporate Governance:** Strong governance practices can mitigate risks and align management's interests with those of shareholders.
#
# 2.2 **Industry Position:**
#    - **Market Share:** Companies with a significant market share are often more resilient to competitive pressures.
#    - **Competitive Advantage:** Assess the company's unique strengths, such as brand reputation, patents, or proprietary technology.
#
# 2.3 **Growth Potential:**
#    - **Innovation and R&D:** Companies investing in research and development may have better long-term growth prospects.
#    - **Market Trends:** Align investments with favorable industry trends, such as technological advancements or demographic shifts.
#
# **3. Risk Assessment:**
#
# 3.1 **Volatility:**
#    - **Beta:** A measure of a stock's volatility relative to the market. A beta less than 1 indicates lower volatility, while a beta greater than 1 suggests higher volatility.
#
# 3.2 **Economic and Political Risks:**
#    - **Geopolitical Exposure:** Consider the impact of political instability or regulatory changes on the company's operations.
#    - **Economic Sensitivity:** Evaluate how economic cycles affect the company's performance.
#
# **4. ESG Considerations:**
#
# 4.1 **Environmental, Social, and Governance (ESG) Factors:**
#    - **Sustainability Practices:** Companies with strong ESG practices may be better positioned for long-term success.
#    - **Social Responsibility:** Evaluate the company's impact on society and its commitment to ethical practices.
#
# **Conclusion:**
#
# The stock selection criteria outlined in this report provide a robust framework for identifying investment opportunities that balance potential returns with risk management. By integrating both quantitative and qualitative factors, investors can make informed decisions that align with their financial goals and risk tolerance. Regular review and adaptation of these criteria are essential to respond to changing market conditions and emerging trends.
#
# **Recommendations:**
#
# - Conduct regular portfolio reviews to ensure alignment with investment objectives.
# - Stay informed about macroeconomic trends and industry developments.
# - Consider diversification to mitigate risks associated with individual stock investments.
#
# **Appendix:**
#
# - **Glossary of Financial Terms**
# - **Industry Benchmark Comparisons**
# - **Case Studies of Successful Stock Selections**
#
# ---
#
# This report serves as a guide for investors seeking to develop a disciplined approach to stock selection, ultimately contributing to a well-constructed investment portfolio.
