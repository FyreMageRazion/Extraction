# %% [markdown]
# # AutoGen - Smart Content Generation
# #### References
# #### https://microsoft.github.io/autogen/0.2/docs/tutorial/introduction

# %%
# pip install pyautogen
from autogen import AssistantAgent, UserProxyAgent, GroupChat, GroupChatManager
from IPython.display import Markdown, display
import os
import numpy as np
import json

# %%
llm_config = {
    "model": "gpt-4o-mini",
    "temperature": 0.3,
}

openai_api_key = "<API KEY>"
os.environ["OPENAI_API_KEY"] = openai_api_key
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
# Out:
# C:\Users\krish\anaconda3\Lib\site-packages\paramiko\pkey.py:82: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from this module in 48.0.0.
#   "cipher": algorithms.TripleDES,
# C:\Users\krish\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.Blowfish and will be removed from this module in 45.0.0.
#   "class": algorithms.Blowfish,
# C:\Users\krish\anaconda3\Lib\site-packages\paramiko\transport.py:243: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from this module in 48.0.0.
#   "class": algorithms.TripleDES,

# %%
content_creator = AssistantAgent(
    name="ContentCreatorAgent",
    llm_config=llm_config,
    system_message=(
        "You are the Content Creator Agent. "
        "Your role is to draft and iteratively refine content on Agentic AI. "
        "Ensure the content is clear, concise, logically structured, "
        "and technically accurate. "
        "When revising, reflect on feedback and improve the draft thoughtfully. "
        "Always respond with the full revised content."
    ),
)

content_critic = AssistantAgent(
    name="ContentCriticAgent",
    llm_config=llm_config,
    system_message=(
        "You are the Content Critic Agent. "
        "Your role is to evaluate drafted content on Agentic AI. "
        "Critically assess language clarity, technical correctness, and completeness. "
        "Provide constructive, actionable feedback. "
        "Do not rewrite the content; only provide feedback and suggestions."
    ),
)

user_proxy = UserProxyAgent(
    name="UserProxy",
    system_message=(
        "You orchestrate the conversation. "
        "Start the discussion and allow agents to interact. "
        "Stop the conversation once the final refined content is produced."
    ),
    human_input_mode="NEVER",
    max_consecutive_auto_reply=5,
    code_execution_config={
        "use_docker": False
    },
)

# %%
group_chat = GroupChat(
    agents=[user_proxy, content_creator, content_critic],
    messages=[],
    max_round=5,
)

group_chat_manager = GroupChatManager(
    groupchat=group_chat,
    llm_config=llm_config,
)

# %%
user_proxy.initiate_chat(
    group_chat_manager,
    message=(
        "Simulate a reflection-based agentic conversation.\n\n"
        "Step 1: Content Creator Agent drafts an initial article on Agentic AI.\n"
        "Step 2: Content Critic Agent evaluates it for language and technical accuracy.\n"
        "Step 3: Content Creator Agent revises the content using reflective reasoning.\n\n"
        "End with the final refined content in MARKDOWN format."
    ),
)
# Out:
# UserProxy (to chat_manager):
#
# Simulate a reflection-based agentic conversation.
#
# Step 1: Content Creator Agent drafts an initial article on Agentic AI.
# Step 2: Content Critic Agent evaluates it for language and technical accuracy.
# Step 3: Content Creator Agent revises the content using reflective reasoning.
#
# End with the final refined content in MARKDOWN format.
#
# --------------------------------------------------------------------------------
#
# Next speaker: ContentCreatorAgent
#
# ContentCreatorAgent (to chat_manager):
#
# ### Step 1: Initial Draft on Agentic AI
#
# **Title: Understanding Agentic AI: The Future of Autonomous Decision-Making**
#
# Agentic AI refers to artificial intelligence systems that possess the ability to make decisions and take actions autonomously, based on their understanding of the environment and objectives. Unlike traditional AI, which relies heavily on human input and predefined rules, agentic AI can adapt and learn from experiences, allowing for more dynamic interactions and solutions.
#
# #### Key Features of Agentic AI
#
# 1. **Autonomy**: Agentic AI operates independently, making decisions without constant human oversight.
# 2. **Learning Capability**: These systems utilize machine learning algorithms to improve their performance over time.
# 3. **Adaptability**: Agentic AI can adjust its strategies based on changing circumstances and new information.
# 4. **Goal-Oriented**: The primary function of agentic AI is to achieve specific objectives, often optimizing for efficiency and effectiveness.
#
# #### Applications of Agentic AI
#
# - **Healthcare**: In medical diagnostics, agentic AI can analyze patient data and suggest treatment plans.
# - **Finance**: These systems can manage investment portfolios by making real-time decisions based on market trends.
# - **Autonomous Vehicles**: Agentic AI enables self-driving cars to navigate complex environments safely.
#
# #### Challenges and Ethical Considerations
#
# While agentic AI presents numerous benefits, it also raises significant ethical concerns. Issues such as accountability, transparency, and bias must be addressed to ensure responsible deployment. The potential for unintended consequences necessitates a careful approach to development and regulation.
#
# ### Step 2: Evaluation by Content Critic Agent
#
# The initial draft provides a solid overview of agentic AI, but it could benefit from improved clarity and depth in certain areas. Here are some suggestions:
#
# 1. **Language Precision**: Some phrases could be more concise. For example, "the ability to make decisions and take actions autonomously" could be simplified to "the ability to make autonomous decisions."
# 2. **Technical Depth**: The explanation of machine learning algorithms lacks specifics. Including examples of common algorithms could enhance understanding.
# 3. **Structure**: The section on challenges could be expanded to include specific examples of ethical dilemmas faced in the deployment of agentic AI.
# 4. **Conclusion**: A concluding statement summarizing the importance of balancing innovation with ethical considerations would strengthen the article.
#
# ### Step 3: Revised Content Using Reflective Reasoning
#
# **Title: Understanding Agentic AI: The Future of Autonomous Decision-Making**
#
# Agentic AI refers to artificial intelligence systems capable of making autonomous decisions and taking actions based on their understanding of the environment and objectives. Unlike traditional AI, which relies on human input and predefined rules, agentic AI adapts and learns from experiences, enabling dynamic interactions and solutions.
#
# #### Key Features of Agentic AI
#
# 1. **Autonomy**: Agentic AI operates independently, making decisions without constant human oversight.
# 2. **Learning Capability**: These systems utilize machine learning algorithms, such as neural networks and reinforcement learning, to enhance their performance over time.
# 3. **Adaptability**: Agentic AI adjusts its strategies based on changing circumstances and new information, allowing for real-time responsiveness.
# 4. **Goal-Oriented**: The primary function of agentic AI is to achieve specific objectives, optimizing for efficiency and effectiveness.
#
# #### Applications of Agentic AI
#
# - **Healthcare**: In medical diagnostics, agentic AI analyzes patient data and suggests treatment plans, improving patient outcomes.
# - **Finance**: These systems manage investment portfolios by making real-time decisions based on market trends, enhancing investment strategies.
# - **Autonomous Vehicles**: Agentic AI enables self-driving cars to navigate complex environments safely, reducing the risk of human error.
#
# #### Challenges and Ethical Considerations
#
# While agentic AI offers numerous benefits, it also raises significant ethical concerns. Issues such as accountability, transparency, and bias must be addressed to ensure responsible deployment. For instance, the use of biased training data can lead to unfair outcomes in decision-making processes. The potential for unintended consequences necessitates a careful approach to development and regulation.
#
# ### Conclusion
#
# Agentic AI represents a transformative advancement in technology, offering the potential for enhanced efficiency and innovation across various sectors. However, as we embrace these advancements, it is crucial to balance innovation with ethical considerations to ensure that these systems are developed and deployed responsibly.
#
# ---
#
# This refined content is structured to provide clarity, depth, and a comprehensive understanding of agentic AI while addressing the ethical implications associated with its use.
#
# --------------------------------------------------------------------------------
#
# Next speaker: ContentCriticAgent
#
# ContentCriticAgent (to chat_manager):
#
# ### Feedback on the Revised Content
#
# The revised content on Agentic AI is significantly improved in terms of clarity and depth. However, there are still areas that could benefit from further refinement. Here are some actionable suggestions:
#
# 1. **Title Clarity**: The title is informative but could be more engaging. Consider using a subtitle to capture the reader's interest, such as "Understanding Agentic AI: The Future of Autonomous Decision-Making and Its Ethical Implications."
#
# 2. **Introduction**: The introduction is clear, but it could be more engaging by starting with a compelling statement or question that highlights the relevance of agentic AI in today's world.
#
# 3. **Key Features**:
#    - The features are well-defined, but consider providing a brief example or application for each feature to illustrate its significance in real-world scenarios.
#    - The term "goal-oriented" could be elaborated upon. What types of goals are typical for agentic AI systems? Providing examples could enhance understanding.
#
# 4. **Applications Section**:
#    - The applications are relevant, but they could be expanded with more specific examples or case studies that demonstrate the impact of agentic AI in each field.
#    - Consider adding a bullet point on applications in sectors like education or manufacturing, which are also relevant to agentic AI.
#
# 5. **Challenges and Ethical Considerations**:
#    - This section is crucial but could be further enhanced by discussing potential solutions or frameworks that are being developed to address these ethical concerns.
#    - Including a brief mention of regulatory bodies or guidelines that are being proposed or implemented could provide context for the reader.
#
# 6. **Conclusion**:
#    - The conclusion effectively summarizes the article but could be more impactful by suggesting a call to action, such as encouraging readers to engage with ongoing discussions about AI ethics or to stay informed about advancements in the field.
#
# 7. **Formatting**:
#    - Consider using bullet points or numbered lists for the challenges and ethical considerations to improve readability.
#    - Adding subheadings within the challenges section could help organize the content better.
#
# ### Overall Impression
# The article provides a comprehensive overview of agentic AI and addresses important ethical considerations. With the suggested enhancements, it could become even more informative and engaging for readers. Focus on providing specific examples and expanding on key points to enrich the content further.
#
# --------------------------------------------------------------------------------
#
# Next speaker: ContentCreatorAgent
#
# ContentCreatorAgent (to chat_manager):
#
# ### Step 3: Further Revised Content Using Reflective Reasoning
#
# **Title: Understanding Agentic AI: The Future of Autonomous Decision-Making and Its Ethical Implications**
#
# In an era where technology is rapidly evolving, agentic AI stands out as a transformative force. But what exactly is agentic AI, and why is it relevant today? Agentic AI refers to artificial intelligence systems capable of making autonomous decisions and taking actions based on their understanding of the environment and objectives. Unlike traditional AI, which relies on human input and predefined rules, agentic AI adapts and learns from experiences, enabling dynamic interactions and innovative solutions.
#
# #### Key Features of Agentic AI
#
# 1. **Autonomy**: Agentic AI operates independently, making decisions without constant human oversight. For example, in smart home systems, agentic AI can adjust heating and lighting based on user preferences without manual input.
#
# 2. **Learning Capability**: These systems utilize machine learning algorithms, such as neural networks and reinforcement learning, to enhance their performance over time. For instance, a recommendation system learns user preferences to suggest personalized content.
#
# 3. **Adaptability**: Agentic AI adjusts its strategies based on changing circumstances and new information, allowing for real-time responsiveness. In supply chain management, agentic AI can reroute deliveries based on traffic conditions.
#
# 4. **Goal-Oriented**: The primary function of agentic AI is to achieve specific objectives, optimizing for efficiency and effectiveness. Common goals include maximizing profit in financial trading or improving patient outcomes in healthcare.
#
# #### Applications of Agentic AI
#
# - **Healthcare**: In medical diagnostics, agentic AI analyzes patient data and suggests treatment plans, significantly improving patient outcomes. For example, IBM Watson Health assists oncologists in identifying personalized treatment options.
#
# - **Finance**: These systems manage investment portfolios by making real-time decisions based on market trends, enhancing investment strategies. Robo-advisors like Betterment use agentic AI to optimize asset allocation for users.
#
# - **Autonomous Vehicles**: Agentic AI enables self-driving cars to navigate complex environments safely, reducing the risk of human error. Companies like Waymo are at the forefront of this technology, developing vehicles that can operate without human intervention.
#
# - **Education**: In personalized learning environments, agentic AI can adapt educational content to meet individual student needs, improving engagement and learning outcomes.
#
# - **Manufacturing**: Agentic AI optimizes production processes by predicting equipment failures and scheduling maintenance, leading to increased efficiency and reduced downtime.
#
# #### Challenges and Ethical Considerations
#
# While agentic AI offers numerous benefits, it also raises significant ethical concerns. Key challenges include:
#
# - **Accountability**: Who is responsible for decisions made by autonomous systems? This question is critical in sectors like healthcare and autonomous driving.
#
# - **Transparency**: Understanding how agentic AI makes decisions is essential for trust. Lack of transparency can lead to skepticism among users.
#
# - **Bias**: If the training data is biased, the AI's decisions may also be biased, leading to unfair outcomes. Addressing this requires diverse and representative datasets.
#
# - **Regulatory Frameworks**: As agentic AI evolves, regulatory bodies are working to establish guidelines to ensure ethical use. For example, the European Union is developing regulations aimed at ensuring AI systems are safe and respect fundamental rights.
#
# #### Conclusion
#
# Agentic AI represents a transformative advancement in technology, offering the potential for enhanced efficiency and innovation across various sectors. However, as we embrace these advancements, it is crucial to balance innovation with ethical considerations. Engaging in ongoing discussions about AI ethics and staying informed about advancements in the field is essential for responsible development and deployment.
#
# ---
#
# This refined content incorporates feedback to enhance clarity, depth, and engagement, providing a comprehensive overview of agentic AI while addressing its ethical implications.
#
# --------------------------------------------------------------------------------
#
# Next speaker: ContentCriticAgent
#
# ContentCriticAgent (to chat_manager):
#
# ### Feedback on the Further Revised Content
#
# The further revised content on Agentic AI is well-structured and effectively addresses many of the previous suggestions. Here are some additional points for consideration to enhance clarity, depth, and engagement:
#
# 1. **Title Engagement**: The title is now more engaging. However, consider making it even more compelling by framing it as a question or a statement that highlights urgency or importance, such as "Agentic AI: Revolutionizing Decision-Making with Ethical Responsibility."
#
# 2. **Introduction**:
#    - The introduction is engaging and poses a relevant question. However, it could benefit from a brief mention of the potential impact of agentic AI on everyday life to further emphasize its relevance.
#    - Consider adding a statistic or a recent development in AI to provide context and capture the reader's attention.
#
# 3. **Key Features**:
#    - The examples provided for each feature are helpful and relevant. However, ensure that the examples are not too specific to one application; consider generalizing them slightly to show broader applicability.
#    - It might be useful to briefly explain how these features interconnect and contribute to the overall effectiveness of agentic AI systems.
#
# 4. **Applications Section**:
#    - The applications are well-chosen and provide a good variety of fields. However, consider adding a brief mention of potential future applications or emerging trends in agentic AI to highlight its evolving nature.
#    - Including a real-world case study or anecdote for one of the applications could further illustrate the impact of agentic AI.
#
# 5. **Challenges and Ethical Considerations**:
#    - The challenges are clearly outlined, but consider providing a brief example or case study for each challenge to illustrate the real-world implications.
#    - You might want to include potential solutions or strategies that are being explored to address these challenges, which would provide a more balanced view.
#
# 6. **Conclusion**:
#    - The conclusion effectively summarizes the article. To enhance its impact, consider reiterating the importance of collaboration among stakeholders (developers, policymakers, and the public) in shaping the future of agentic AI.
#    - A call to action could be more explicit, encouraging readers to participate in discussions or initiatives related to AI ethics.
#
# 7. **Formatting**:
#    - The use of bullet points and subheadings is effective for readability. Consider using bold or italics for key terms to draw attention to important concepts.
#    - Adding visuals, such as diagrams or infographics, could enhance understanding, especially in explaining complex concepts like machine learning algorithms.
#
# ### Overall Impression
# The article is well-crafted and provides a comprehensive overview of agentic AI, addressing both its potential and ethical considerations. With the suggested enhancements, it could become even more informative and engaging for readers. Focus on providing specific examples and expanding on key points to enrich the content further.
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (c51e66de-f2a5-45a6-a0cd-e19e6081d7a1): Maximum rounds (5) reached
# ChatResult(chat_id=None, chat_history=[{'content': 'Simulate a reflection-based agentic conversation.\n\nStep 1: Content Creator Agent drafts an initial article on Agentic AI.\nStep 2: Content Critic Agent evaluates it for language and technical accuracy.\nStep 3: Content Creator Agent revises the content using reflective reasoning.\n\nEnd with the final refined content in MARKDOWN format.', 'role': 'assistant', 'name': 'UserProxy'}, {'content': '### Step 1: Initial Draft on Agentic AI\n\n**Title: Understanding Agentic AI: The Future of Autonomous Decision-Making**\n\nAgentic AI refers to artificial intelligence systems that possess the ability to make decisions and take actions autonomously, based on their understanding of the environment and objectives. Unlike traditional AI, which relies heavily on human input and predefined rules, agentic AI can adapt and learn from experiences, allowing for more dynamic interactions and solutions.\n\n#### Key Features of Agentic AI\n\n1. **Autonomy**: Agentic AI operates independently, making decisions without constant human oversight.\n2. **Learning Capability**: These systems utilize machine learning algorithms to improve their performance over time.\n3. **Adaptability**: Agentic AI can adjust its strategies based on changing circumstances and new information.\n4. **Goal-Oriented**: The primary function of agentic AI is to achieve specific objectives, often optimizing for efficiency and effectiveness.\n\n#### Applications of Agentic AI\n\n- **Healthcare**: In medical diagnostics, agentic AI can analyze patient data and suggest treatment plans.\n- **Finance**: These systems can manage investment portfolios by making real-time decisions based on market trends.\n- **Autonomous Vehicles**: Agentic AI enables self-driving cars to navigate complex environments safely.\n\n#### Challenges and Ethical Considerations\n\nWhile agentic AI presents numerous benefits, it also raises significant ethical concerns. Issues such as accountability, transparency, and bias must be addressed to ensure responsible deployment. The potential for unintended consequences necessitates a careful approach to development and regulation.\n\n### Step 2: Evaluation by Content Critic Agent\n\nThe initial draft provides a solid overview of agentic AI, but it could benefit from improved clarity and depth in certain areas. Here are some suggestions:\n\n1. **Language Precision**: Some phrases could be more concise. For example, "the ability to make decisions and take actions autonomously" could be simplified to "the ability to make autonomous decisions."\n2. **Technical Depth**: The explanation of machine learning algorithms lacks specifics. Including examples of common algorithms could enhance understanding.\n3. **Structure**: The section on challenges could be expanded to include specific examples of ethical dilemmas faced in the deployment of agentic AI.\n4. **Conclusion**: A concluding statement summarizing the importance of balancing innovation with ethical considerations would strengthen the article.\n\n### Step 3: Revised Content Using Reflective Reasoning\n\n**Title: Understanding Agentic AI: The Future of Autonomous Decision-Making**\n\nAgentic AI refers to artificial intelligence systems capable of making autonomous decisions and taking actions based on their understanding of the environment and objectives. Unlike traditional AI, which relies on human input and predefined rules, agentic AI adapts and learns from experiences, enabling dynamic interactions and solutions.\n\n#### Key Features of Agentic AI\n\n1. **Autonomy**: Agentic AI operates independently, making decisions without constant human oversight.\n2. **Learning Capability**: These systems utilize machine learning algorithms, such as neural networks and reinforcement learning, to enhance their performance over time.\n3. **Adaptability**: Agentic AI adjusts its strategies based on changing circumstances and new information, allowing for real-time responsive ...

# %%
messages = group_chat.messages

final_message = None
for msg in reversed(messages):
    if msg["name"] == "ContentCreatorAgent":
        final_message = msg["content"]
        break

if final_message:
    display(Markdown(final_message))
else:
    print("No final content found.")
# Out:
# ### Step 3: Further Revised Content Using Reflective Reasoning
#
# **Title: Understanding Agentic AI: The Future of Autonomous Decision-Making and Its Ethical Implications**
#
# In an era where technology is rapidly evolving, agentic AI stands out as a transformative force. But what exactly is agentic AI, and why is it relevant today? Agentic AI refers to artificial intelligence systems capable of making autonomous decisions and taking actions based on their understanding of the environment and objectives. Unlike traditional AI, which relies on human input and predefined rules, agentic AI adapts and learns from experiences, enabling dynamic interactions and innovative solutions.
#
# #### Key Features of Agentic AI
#
# 1. **Autonomy**: Agentic AI operates independently, making decisions without constant human oversight. For example, in smart home systems, agentic AI can adjust heating and lighting based on user preferences without manual input.
#
# 2. **Learning Capability**: These systems utilize machine learning algorithms, such as neural networks and reinforcement learning, to enhance their performance over time. For instance, a recommendation system learns user preferences to suggest personalized content.
#
# 3. **Adaptability**: Agentic AI adjusts its strategies based on changing circumstances and new information, allowing for real-time responsiveness. In supply chain management, agentic AI can reroute deliveries based on traffic conditions.
#
# 4. **Goal-Oriented**: The primary function of agentic AI is to achieve specific objectives, optimizing for efficiency and effectiveness. Common goals include maximizing profit in financial trading or improving patient outcomes in healthcare.
#
# #### Applications of Agentic AI
#
# - **Healthcare**: In medical diagnostics, agentic AI analyzes patient data and suggests treatment plans, significantly improving patient outcomes. For example, IBM Watson Health assists oncologists in identifying personalized treatment options.
#
# - **Finance**: These systems manage investment portfolios by making real-time decisions based on market trends, enhancing investment strategies. Robo-advisors like Betterment use agentic AI to optimize asset allocation for users.
#
# - **Autonomous Vehicles**: Agentic AI enables self-driving cars to navigate complex environments safely, reducing the risk of human error. Companies like Waymo are at the forefront of this technology, developing vehicles that can operate without human intervention.
#
# - **Education**: In personalized learning environments, agentic AI can adapt educational content to meet individual student needs, improving engagement and learning outcomes.
#
# - **Manufacturing**: Agentic AI optimizes production processes by predicting equipment failures and scheduling maintenance, leading to increased efficiency and reduced downtime.
#
# #### Challenges and Ethical Considerations
#
# While agentic AI offers numerous benefits, it also raises significant ethical concerns. Key challenges include:
#
# - **Accountability**: Who is responsible for decisions made by autonomous systems? This question is critical in sectors like healthcare and autonomous driving.
#
# - **Transparency**: Understanding how agentic AI makes decisions is essential for trust. Lack of transparency can lead to skepticism among users.
#
# - **Bias**: If the training data is biased, the AI's decisions may also be biased, leading to unfair outcomes. Addressing this requires diverse and representative datasets.
#
# - **Regulatory Frameworks**: As agentic AI evolves, regulatory bodies are working to establish guidelines to ensure ethical use. For example, the European Union is developing regulations aimed at ensuring AI systems are safe and respect fundamental rights.
#
# #### Conclusion
#
# Agentic AI represents a transformative advancement in technology, offering the potential for enhanced efficiency and innovation across various sectors. However, as we embrace these advancements, it is crucial to balance innovation with ethical considerations. Engaging in ongoing discussions about AI ethics and staying informed about advancements in the field is essential for responsible development and deployment.
#
# ---
#
# This refined content incorporates feedback to enhance clarity, depth, and engagement, providing a comprehensive overview of agentic AI while addressing its ethical implications.
